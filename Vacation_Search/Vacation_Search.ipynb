# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
gmaps.__version__
# Out:
# '0.9.0'

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID        City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0   Mahebourg      MU -20.4081   57.7000     80.60        78
# 1        1  Port Hardy      CA  50.6996 -127.4199     46.40        81
# 2        2    Cidreira      BR -30.1811  -50.2056     78.84        63
# 3        3      Albany      US  42.6001  -73.9662     36.00        30
# 4        4        Asau      RO  46.4333   26.4000     45.00        45
#
#    Cloudiness  Wind Speed Current Description
# 0          75        9.22       broken clouds
# 1          90       12.66     overcast clouds
# 2          19        8.59          few clouds
# 3           0        3.00           clear sky
# 4          54        3.76          light rain

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 

min_temp  = float(input ("Enter minimum temperature:"))
max_temp  = float(input ("Enter maximum temperature:"))
# Out:
# Enter minimum temperature:-32.0
# Enter maximum temperature:90.0

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.

temp_filter_data_df= city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) | (city_data_df["Max Temp"] >= min_temp)]

temp_filter_data_df.head()
#city_data_df["Max Temp"]
# Out:
#    City_ID        City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0   Mahebourg      MU -20.4081   57.7000     80.60        78
# 1        1  Port Hardy      CA  50.6996 -127.4199     46.40        81
# 2        2    Cidreira      BR -30.1811  -50.2056     78.84        63
# 3        3      Albany      US  42.6001  -73.9662     36.00        30
# 4        4        Asau      RO  46.4333   26.4000     45.00        45
#
#    Cloudiness  Wind Speed Current Description
# 0          75        9.22       broken clouds
# 1          90       12.66     overcast clouds
# 2          19        8.59          few clouds
# 3           0        3.00           clear sky
# 4          54        3.76          light rain

# %%
# 4a. Determine if there are any empty rows.
temp_filter_data_df.isnull().sum()
# Out:
# City_ID                 0
# City                    0
# Country                13
# Lat                     0
# Lng                     0
# Max Temp                0
# Humidity                0
# Cloudiness              0
# Wind Speed              0
# Current Description     0
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
temp_filter_data2_df=temp_filter_data_df.dropna()
temp_filter_data2_df.isnull().sum()
# Out:
# City_ID                0
# City                   0
# Country                0
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = temp_filter_data2_df[["City", "Country", "Max Temp","Current Description", "Lat", "Lng"]].copy()


# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.tail(10)
# Out:
#                  City Country  Max Temp Current Description      Lat  \
# 1890          Ushtobe      KZ     17.15                snow  45.2514
# 1891  Santiago De Cao      PE     73.40                 fog  -7.9589
# 1892      Champagnole      FR     41.00          light rain  46.7445
# 1893         Mishkino      RU      9.84           clear sky  55.3389
# 1894     Barreirinhas      BR     84.16     overcast clouds  -2.7469
# 1896          Teguise      ES     68.00    scattered clouds  29.0605
# 1897          Bushehr      IR     66.20                sand  28.9684
# 1898            Arras      FR     51.01     overcast clouds  50.2930
# 1899            Basco      PH     73.85    scattered clouds  20.4487
# 1900            Jhang      PK     66.00       moderate rain  33.6748
#
#            Lng Hotel Name
# 1890   77.9838
# 1891  -79.2392
# 1892    5.9135
# 1893   63.9175
# 1894  -42.8264
# 1896  -13.5640
# 1897   50.8385
# 1898    2.7819
# 1899  121.9702
# 1900   72.6963

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 10000,
    "types": "lodging",
    "key": g_key,
    "location": "42.6001, -73.9662"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

hotels
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 42.606152, 'lng': -73.888217},
#     'viewport': {'northeast': {'lat': 42.60782828029151,
#       'lng': -73.88677596970848},
#      'southwest': {'lat': 42.60513031970851, 'lng': -73.88947393029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'The Inn at Deer Meadow',
#    'permanently_closed': True,
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106582852514373932947">Richard Boyd</a>'],
#      'photo_reference': 'ATtYBwJ6Mpbu8n81sRaKL3BWB-1g7MDC2hy6TgVpH5v1OIDbzB5dF3hXgJFtqwAdTmeldawM79j3MMUA0CF8ABy6onLwpeIp2UZ6yZLYTtYpRZzEfFmjyYRZSsRn-VwmIzo4ps783r8ftTzwWYc10uDLzc0JwbeLFty8zqbXVf3OVDp_vG2R',
#      'width': 4032}],
#    'place_id': 'ChIJAbFUW1Xe3YkRFitPd54ZQ8Y',
#    'plus_code': {'compound_code': 'J446+FP Delmar, NY, USA',
# ...

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 20000,
    "type": "lodging",
    "key": g_key
}

 
# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
        
    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# ...

# %%
hotel_df.head(200)
# Out:
#                City Country  Max Temp Current Description      Lat       Lng  \
# 0         Mahebourg      MU     80.60       broken clouds -20.4081   57.7000
# 1        Port Hardy      CA     46.40     overcast clouds  50.6996 -127.4199
# 2          Cidreira      BR     78.84          few clouds -30.1811  -50.2056
# 3            Albany      US     36.00           clear sky  42.6001  -73.9662
# 4              Asau      RO     45.00          light rain  46.4333   26.4000
# ..              ...     ...       ...                 ...      ...       ...
# 198    Saint-Pierre      RE     78.80           clear sky -21.3393   55.4781
# 199        Taicheng      CN     42.49           clear sky  38.7310  113.2280
# 200   Mar Del Plata      AR     75.20           clear sky -38.0023  -57.5575
# 201        Khatanga      RU    -13.83     overcast clouds  71.9667  102.5000
# 202  Ciudad Bolivar      VE     88.52     overcast clouds   8.1222  -63.5497
#
#                                   Hotel Name
# ...

# %%
# 7. Drop the rows where there is no Hotel Name. (I ran out of api calls due to the large amount of )
import numpy as np
hotel_df["Hotel Name"] =hotel_df["Hotel Name"].replace('',np.nan)

hotel_df
# Out:
#             City Country  Max Temp Current Description      Lat       Lng  \
# 0      Mahebourg      MU     80.60       broken clouds -20.4081   57.7000
# 1     Port Hardy      CA     46.40     overcast clouds  50.6996 -127.4199
# 2       Cidreira      BR     78.84          few clouds -30.1811  -50.2056
# 3         Albany      US     36.00           clear sky  42.6001  -73.9662
# 4           Asau      RO     45.00          light rain  46.4333   26.4000
# ...          ...     ...       ...                 ...      ...       ...
# 1896     Teguise      ES     68.00    scattered clouds  29.0605  -13.5640
# 1897     Bushehr      IR     66.20                sand  28.9684   50.8385
# 1898       Arras      FR     51.01     overcast clouds  50.2930    2.7819
# 1899       Basco      PH     73.85    scattered clouds  20.4487  121.9702
# 1900       Jhang      PK     66.00       moderate rain  33.6748   72.6963
#
#                                    Hotel Name
# ...

# %%
# 8a. Create the output File (CSV)
clean_hotel_df = hotel_df.dropna()
output_data_file = "weather_database/WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.0)

# %%
# 11a. Add a marker layer for each city to the map. 
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
